# %% [markdown]
# # Intorduction

# %%
# Setup
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
# Avoid OMM Error
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# check the GPU
physical_devices
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# define the images directory
data_dir = "data/PLD_3_Classes_256"
print(os.listdir(data_dir))
# Out:
# ['Testing', 'Training', 'Validation']

# %%
# let`s make EDA for the dataset
data_splits = os.listdir(data_dir)
for data_kind in data_splits:
    classes = os.listdir(os.path.join(data_dir,data_kind))
    print(f'*We Process the {data_kind}')
    for class_ in classes:
        path = os.path.join(os.path.join(data_dir,data_kind),class_)
        print(f'  we have a {len(os.listdir(path))} images from class {class_}')
    print('')
# Out:
# *We Process the Testing
#   we have a 162 images from class Early_Blight
#   we have a 102 images from class Healthy
#   we have a 141 images from class Late_Blight
#
# *We Process the Training
#   we have a 1303 images from class Early_Blight
#   we have a 816 images from class Healthy
#   we have a 1132 images from class Late_Blight
#
# *We Process the Validation
#   we have a 163 images from class Early_Blight
#   we have a 102 images from class Healthy
#   we have a 151 images from class Late_Blight

# %%
# Filter out Corrupted images

num_skipped = 0
data_splits = os.listdir(data_dir)

for data_kind in data_splits:
    data_kind_path = os.path.join(data_dir,data_kind)
    print(f'*We Process the {data_kind}')
    
    classes = os.listdir(data_kind_path)
    for class_ in classes:
        folder_path = os.path.join(data_kind_path,class_)
        for fname in os.listdir(folder_path):
            fpath = os.path.join(folder_path,fname)

            try:
                fobj = open(fpath,"rb")
                is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
            finally:
                fobj.close()

            if not is_jfif:
                num_skipped += 1
                os.remove(fpath)
    print(f"  Deleted {num_skipped} Images for {data_kind}\n")
# Out:
# *We Process the Testing
#   Deleted 0 Images for Testing
#
# *We Process the Training
#   Deleted 0 Images for Training
#
# *We Process the Validation
#   Deleted 0 Images for Validation

# %% [markdown]
# # Genrate a Dataset and Visualize

# %%
# load data with tf.utils.image_dataset_from_directory
IMAGE_SIZE = (256,256)
BATCH_SIZE = 16
SEED = 42

# make train-testing-validation datasets
def load_data(data_dir):
    data = []
    for class_d in os.listdir(data_dir):
        data.append(
            tf.keras.utils.image_dataset_from_directory(
            os.path.join(data_dir,class_d),
            image_size = IMAGE_SIZE,
            batch_size = BATCH_SIZE,
            seed = SEED)
                   )
    return data
# apllying the Load dataset
test_ds, train_ds, val_ds = load_data(data_dir)
# Out:
# Found 405 files belonging to 3 classes.
# Found 3251 files belonging to 3 classes.
# Found 416 files belonging to 3 classes.

# %%
# plot Visualize 
plt.figure(figsize=(10,10))
for image, label in train_ds.take(1):
    for i in range(9):
        plt.subplot(3, 3, i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(train_ds.class_names[label[i]])
        plt.axis("off");

# %% [markdown]
# ## Standardize the data

# %%
# standardize values to be in the [0,1] range
normalization_layer = tf.keras.layers.Rescaling(1./255)

# using thr Dataset.map to apply this layer
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))

# check pixels after normalization
images_batch, label_batch = next(iter(normalized_ds))
random_image = images_batch[4]
print(f' min value = {np.min(random_image)} , max value =  {np.max(random_image)}')
# Out:
#  min value = 0.0 , max value =  0.9725490808486938

# %% [markdown]
# # Configure the dataset for performance

# %%
# make sure to use buffered prefetching , yield the data without having I/O become bloking
def Configure(dataset):
    dataset = dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset

# apply the function
train_ds = Configure(train_ds)
val_ds = Configure(val_ds)

# %% [markdown]
# # Build a Model

# %%
# build a small version of the `Xception Network`

NUM_CLASSES = 3
INPUT_SHAPE = IMAGE_SIZE +(3,)
model = tf.keras.Sequential([
    
    # rescaling and Data augmentation block
    tf.keras.layers.RandomFlip("horizontal_and_vertical", input_shape=INPUT_SHAPE),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.Rescaling(1.0/255),
    
    # Conv2D Block
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    # Flatten Block
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    
],name = "Mido")


# plot the model
keras.utils.plot_model(model, show_shapes=True)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
# Compile the Model  
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy'])

# %%
# Define Callback
class CustomCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if (logs.get('val_accuracy')>=0.95):   
            keys = list(logs.keys())
            print("End epoch {} of training; got log keys: {}".format(epoch, keys))
            self.model.stop_training = True
            
# define object from CustomCallback Class
callbacks = CustomCallback()

# %%
# training the model
EPOCHS = 50
history = model.fit(
                    train_ds,
                    validation_data=val_ds,
                    epochs =EPOCHS,
                    callbacks=[callbacks])
# Out:
# Epoch 1/50
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 204/204 [==============================] - 69s 285ms/step - loss: 1.0201 - accuracy: 0.4946 - val_loss: 1.1723 - val_accuracy: 0.5168
# Epoch 2/50
# 204/204 [==============================] - 78s 382ms/step - loss: 0.9006 - accuracy: 0.5897 - val_loss: 0.7678 - val_accuracy: 0.6538
# Epoch 3/50
# 204/204 [==============================] - 78s 384ms/step - loss: 0.7519 - accuracy: 0.6789 - val_loss: 0.6682 - val_accuracy: 0.7308
# Epoch 4/50
# 204/204 [==============================] - 79s 387ms/step - loss: 0.5725 - accuracy: 0.7708 - val_loss: 0.5358 - val_accuracy: 0.8029
# Epoch 5/50
# 204/204 [==============================] - 77s 379ms/step - loss: 0.4343 - accuracy: 0.8397 - val_loss: 0.3695 - val_accuracy: 0.8438
# Epoch 6/50
# 204/204 [==============================] - 73s 357ms/step - loss: 0.3546 - accuracy: 0.8696 - val_loss: 0.3028 - val_accuracy: 0.8798
# Epoch 7/50
# 204/204 [==============================] - 66s 325ms/step - loss: 0.2843 - accuracy: 0.8988 - val_loss: 0.6199 - val_accuracy: 0.7837
# Epoch 8/50
# 204/204 [==============================] - 71s 349ms/step - loss: 0.2521 - accuracy: 0.9145 - val_loss: 0.2309 - val_accuracy: 0.9255
# Epoch 9/50
# 204/204 [==============================] - 68s 332ms/step - loss: 0.2055 - accuracy: 0.9326 - val_loss: 0.2081 - val_accuracy: 0.9207
# Epoch 10/50
# 204/204 [==============================] - 63s 311ms/step - loss: 0.1856 - accuracy: 0.9329 - val_loss: 0.1974 - val_accuracy: 0.9255
# Epoch 11/50
# 204/204 [==============================] - 60s 294ms/step - loss: 0.1502 - accuracy: 0.9483 - val_loss: 0.1833 - val_accuracy: 0.9303
# Epoch 12/50
# 204/204 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9483End epoch 11 of training; got log keys: ['loss', 'accuracy', 'val_loss', 'val_accuracy']
# 204/204 [==============================] - 60s 293ms/step - loss: 0.1524 - accuracy: 0.9483 - val_loss: 0.1378 - val_accuracy: 0.9615

# %% [markdown]
# # Model Evaluation

# %%
# list all data in history
print(history.history.keys())
print("")
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')

# summarize history for loss
plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evalute model
model.evaluate(test_ds)
# Out:
# 26/26 [==============================] - 2s 56ms/step - loss: 0.1716 - accuracy: 0.9654
# [0.17162027955055237, 0.9654321074485779]

# %%
# To Color The Output
from termcolor import colored

# %%
# ok everythink look nice, let`s check pic manually
for image_batch, label_batch in test_ds.take(1):
    idx = np.random.randint(0,15)
    print(f"The Real Image was: ",colored({test_ds.class_names[label[idx]]}, 'red'),"\n")
    plt.imshow(image_batch[idx].numpy().astype('uint8'))
    plt.title(test_ds.class_names[label[idx]])
    plt.axis("off");
    plt.show()
    
    print(f"\nThe Model Prediction was: \n")
    print(image_batch.shape)
    pred = model.predict(image_batch)
    pred_idx = np.argmax(pred[idx])
    confidence = str(round(100*(np.max(pred[idx])), 2)) + " %"
    print("")
    print("Class From Model Prediction is :",colored({test_ds.class_names[label[pred_idx]]}, 'green')," with confidence =",colored({confidence},'yellow'))
# Out:
# The Real Image was:  {'Early_Blight'}
# The Model Prediction was:
#
# (16, 256, 256, 3)
# 1/1 [==============================] - 0s 43ms/step
#
# Class From Model Prediction is : {'Early_Blight'}  with confidence = {'100.0 %'}

# %%
# saving the model
model.save('save_model')
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: save_model\assets
# INFO:tensorflow:Assets written to: save_model\assets

# %% [markdown]
# # Convert to ONNX

# %%
# Convert to ONNX using the Python API

import tf2onnx
import onnxruntime as rt

spec = (tf.TensorSpec((None, 256, 256, 3), tf.float32, name="input"),)
output_path = model.name + ".onnx"

model_proto, _ = tf2onnx.convert.from_keras(model, input_signature=spec, opset=13, output_path=output_path)
output_names = [n.name for n in model_proto.graph.output]

# %%
# Convert to ONNX using the command line

# !python3 -m tf2onnx.convert --opset 13 \
    --saved-model {os.path.join("","save_model" )} \
    --output  {os.path.join("save_model", model.name + ".onnx")}
# Out:
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.10.0\lib\runpy.py:126: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2023-01-21 18:47:45,544 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2023-01-21 18:47:47,496 - INFO - Signatures found in model: [serving_default].
# 2023-01-21 18:47:47,496 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2023-01-21 18:47:47,496 - INFO - Output names: ['dense_1']
# 2023-01-21 18:47:47,788 - INFO - Using tensorflow=2.10.0, onnx=1.13.0, tf2onnx=1.13.0/434b4a
# 2023-01-21 18:47:47,788 - INFO - Using opset <onnx, 13>
# 2023-01-21 18:47:47,857 - INFO - Computed 0 values for constant folding
# 2023-01-21 18:47:47,922 - INFO - Optimizing ONNX model
# 2023-01-21 18:47:48,169 - INFO - After optimization: Cast -1 (1->0), Identity -2 (2->0), Transpose -14 (16->2)
# 2023-01-21 18:47:48,323 - INFO -
# 2023-01-21 18:47:48,323 - INFO - Successfully converted TensorFlow model save_model to ONNX
# 2023-01-21 18:47:48,324 - INFO - Model inputs: ['random_flip_input']
# 2023-01-21 18:47:48,324 - INFO - Model outputs: ['dense_1']
# 2023-01-21 18:47:48,324 - INFO - ONNX model is saved at save_model\Mido.onnx

# %%
path = os.path.join("\save_model", model.name + ".onnx")
print(path)
# Out:
# \save_model\Mido.onnx
